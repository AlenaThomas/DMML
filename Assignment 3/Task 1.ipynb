# %% [markdown]
# # **DMML ASSIGNMENT 3**
# ## **TASK 1. Fashion MNIST dataset**
#
# Name: Alena Maria Thomas, Ananya Kaushal
#
# Roll No: MDS202303, MDS202306

# %% [markdown]
# ### 1. Import required packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.datasets import fashion_mnist
from keras.layers import Flatten, Dense, Dropout
from keras.models import Sequential
from keras.utils import to_categorical

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances

# %% [markdown]
# ### 2. Load the dataset.

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
print("original shape of X_train:", X_train.shape)
print("original shape of X_test:", X_test.shape)
# Out:
# original shape of X_train: (60000, 28, 28)
# original shape of X_test: (10000, 28, 28)

# %% [markdown]
# ### 3. Preprocess the dataset.

# %% [markdown]
# The training set contains 60,000 grayscale images, each 28x28 pixels.
#
# Each pixel intensity is represented as a byte (0 to 255):

# %%
X_train.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# Therefore, normalize the data i.e. scaling the pixel intensities down to $[0, 1]$ and convert to floats, by dividing by 255.

# %%
X_train = X_train / 255.
X_test = X_test / 255.

# %% [markdown]
# ### 4. Define function to perform K-Means Clustering to obtain a small representative labeled subset.

# %%
def KMeans_seed_set(X, y, k):
  # Flatten the images for clustering
  x_train = X.reshape(X.shape[0], -1)

  # Fit KMeans model
  kmeans = KMeans(n_clusters=k, random_state=100)
  kmeans.fit(x_train)

  # Obtain the centroids and clusters
  centroids = kmeans.cluster_centers_
  cluster_labels = kmeans.labels_

  # initialize a numpy arrays to store the seed set.
  seed_set_X = np.zeros((k, X.shape[1], X.shape[1]))
  seed_set_y =  np.zeros(k)

  # for each cluster, find the nearest image to the centroid
  for i in range(k):
    # Get all features in this cluster i
    cluster_features = x_train[cluster_labels == i]

    # Compute the Euclidean distance to the centroid
    distances = euclidean_distances(cluster_features, [centroids[i]])

    # Find index of nearest image
    nearest_idx = np.argmin(distances)

    # Find the corresponding data point and label
    datapoint = X[cluster_labels == i][nearest_idx]
    idx = np.where((X == datapoint).all(axis=1))[0]
    label = y[idx][0]

    # Add this datapoint to the seed set.
    seed_set_X[i] = datapoint
    seed_set_y[i] = label

  return (seed_set_X, seed_set_y)

# %% [markdown]
# ### 5. Define functions to build and train the MLP model on the representative set.

# %%
#create a simple MLP model
def create_mlp_model():
  tf.keras.backend.clear_session() # to reset the name counters
  tf.random.set_seed(100)

  model = Sequential([
      Flatten(input_shape=[28,28]),
      Dense(512, activation='relu'),
      Dropout(0.2),
      Dense(100, activation='relu'),
      Dropout(0.2),
      Dense(10, activation='softmax')
  ])
  model.compile(
    loss = 'categorical_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
  )
  return model

# %%
def train_mlp_model(model, X, y):
  # one-hot encode the target variable
  new_y = to_categorical(y)

  # Set up early stopping to prevent overfitting
  early_stop = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)

  # train the MLP model
  history = model.fit(X, new_y, batch_size=128, epochs=25, verbose=1,
                      callbacks=[early_stop], shuffle=True)

  return history

# %% [markdown]
# ### 6. Compare the accuracy of the trained MLP model for different values of $K$.

# %%
k_values = [10, 20, 30, 40, 50]

# %%
training_accuracy = {}
models = {}

for k in k_values:
  # obtain seed set after applying KMeans clustering
  seed_X, seed_y = KMeans_seed_set(X_train, y_train, k)

  # Build an MLP model
  model = create_mlp_model()

  # Train an MLP model using this set
  history = train_mlp_model(model, X_train, y_train)

  training_accuracy[k] = round(history.history['accuracy'][-1], 4)

  models[k] = model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Epoch 1/25
# 469/469 [==============================] - 9s 16ms/step - loss: 0.5612 - accuracy: 0.7994
# Epoch 2/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.4046 - accuracy: 0.8534
# Epoch 3/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.3640 - accuracy: 0.8684
# Epoch 4/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.3419 - accuracy: 0.8758
# Epoch 5/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3198 - accuracy: 0.8827
# Epoch 6/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3108 - accuracy: 0.8867
# Epoch 7/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2981 - accuracy: 0.8902
# Epoch 8/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2889 - accuracy: 0.8930
# Epoch 9/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2799 - accuracy: 0.8964
# Epoch 10/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2716 - accuracy: 0.8982
# Epoch 11/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2650 - accuracy: 0.8995
# Epoch 12/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2577 - accuracy: 0.9030
# Epoch 13/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2542 - accuracy: 0.9033
# Epoch 14/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2463 - accuracy: 0.9066
# Epoch 15/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2433 - accuracy: 0.9082
# Epoch 16/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2377 - accuracy: 0.9107
# Epoch 17/25
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2327 - accuracy: 0.9120
# Epoch 18/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2291 - accuracy: 0.9131
# Epoch 19/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2236 - accuracy: 0.9141
# Epoch 20/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2184 - accuracy: 0.9168
# Epoch 21/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2164 - accuracy: 0.9182
# Epoch 22/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2104 - accuracy: 0.9203
# Epoch 23/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2079 - accuracy: 0.9216
# Epoch 24/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2066 - accuracy: 0.9215
# Epoch 25/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2011 - accuracy: 0.9234
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Epoch 1/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.5590 - accuracy: 0.8032
# Epoch 2/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.4021 - accuracy: 0.8539
# Epoch 3/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.3633 - accuracy: 0.8683
# Epoch 4/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.3400 - accuracy: 0.8751
# Epoch 5/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3224 - accuracy: 0.8815
# Epoch 6/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3087 - accuracy: 0.8858
# Epoch 7/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2972 - accuracy: 0.8906
# Epoch 8/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2897 - accuracy: 0.8913
# Epoch 9/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2825 - accuracy: 0.8954
# Epoch 10/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2730 - accuracy: 0.8982
# Epoch 11/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2662 - accuracy: 0.8994
# Epoch 12/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2589 - accuracy: 0.9021
# Epoch 13/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2511 - accuracy: 0.9053
# Epoch 14/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2468 - accuracy: 0.9067
# Epoch 15/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2418 - accuracy: 0.9079
# Epoch 16/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2352 - accuracy: 0.9101
# Epoch 17/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2308 - accuracy: 0.9118
# Epoch 18/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.2273 - accuracy: 0.9138
# Epoch 19/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2227 - accuracy: 0.9158
# Epoch 20/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2203 - accuracy: 0.9173
# Epoch 21/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2126 - accuracy: 0.9193
# Epoch 22/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2085 - accuracy: 0.9201
# Epoch 23/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2048 - accuracy: 0.9213
# Epoch 24/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2068 - accuracy: 0.9205
# Epoch 25/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1999 - accuracy: 0.9231
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Epoch 1/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.5555 - accuracy: 0.8029
# Epoch 2/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3995 - accuracy: 0.8559
# Epoch 3/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3610 - accuracy: 0.8695
# Epoch 4/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.3385 - accuracy: 0.8763
# Epoch 5/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.3201 - accuracy: 0.8815
# Epoch 6/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.3067 - accuracy: 0.8860
# Epoch 7/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2991 - accuracy: 0.8885
# Epoch 8/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2882 - accuracy: 0.8934
# Epoch 9/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2769 - accuracy: 0.8965
# Epoch 10/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2697 - accuracy: 0.8990
# Epoch 11/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2649 - accuracy: 0.9005
# Epoch 12/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2553 - accuracy: 0.9035
# Epoch 13/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2536 - accuracy: 0.9040
# Epoch 14/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2483 - accuracy: 0.9071
# Epoch 15/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2398 - accuracy: 0.9083
# Epoch 16/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2337 - accuracy: 0.9116
# Epoch 17/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2311 - accuracy: 0.9112
# Epoch 18/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2275 - accuracy: 0.9129
# Epoch 19/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2227 - accuracy: 0.9160
# Epoch 20/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2178 - accuracy: 0.9178
# Epoch 21/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2134 - accuracy: 0.9183
# Epoch 22/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2115 - accuracy: 0.9197
# Epoch 23/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2075 - accuracy: 0.9213
# Epoch 24/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2043 - accuracy: 0.9218
# Epoch 25/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2018 - accuracy: 0.9228
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Epoch 1/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.5531 - accuracy: 0.8035
# Epoch 2/25
# 469/469 [==============================] - 8s 16ms/step - loss: 0.3991 - accuracy: 0.8557
# Epoch 3/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3577 - accuracy: 0.8680
# Epoch 4/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.3387 - accuracy: 0.8759
# Epoch 5/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.3222 - accuracy: 0.8820
# Epoch 6/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3080 - accuracy: 0.8864
# Epoch 7/25
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2978 - accuracy: 0.8904
# Epoch 8/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2885 - accuracy: 0.8928
# Epoch 9/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2789 - accuracy: 0.8964
# Epoch 10/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2709 - accuracy: 0.8993
# Epoch 11/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2617 - accuracy: 0.9024
# Epoch 12/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2572 - accuracy: 0.9034
# Epoch 13/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2537 - accuracy: 0.9051
# Epoch 14/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2458 - accuracy: 0.9075
# Epoch 15/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2381 - accuracy: 0.9105
# Epoch 16/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2368 - accuracy: 0.9095
# Epoch 17/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2317 - accuracy: 0.9126
# Epoch 18/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2293 - accuracy: 0.9123
# Epoch 19/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2230 - accuracy: 0.9154
# Epoch 20/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2177 - accuracy: 0.9175
# Epoch 21/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2156 - accuracy: 0.9190
# Epoch 22/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2094 - accuracy: 0.9196
# Epoch 23/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.2067 - accuracy: 0.9209
# Epoch 24/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2059 - accuracy: 0.9216
# Epoch 25/25
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1993 - accuracy: 0.9240
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Epoch 1/25
# 469/469 [==============================] - 8s 15ms/step - loss: 0.5536 - accuracy: 0.8029
# Epoch 2/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3980 - accuracy: 0.8552
# Epoch 3/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.3613 - accuracy: 0.8671
# Epoch 4/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3374 - accuracy: 0.8770
# Epoch 5/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.3216 - accuracy: 0.8818
# Epoch 6/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3089 - accuracy: 0.8868
# Epoch 7/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3009 - accuracy: 0.8887
# Epoch 8/25
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2909 - accuracy: 0.8924
# Epoch 9/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2787 - accuracy: 0.8956
# Epoch 10/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2742 - accuracy: 0.8978
# Epoch 11/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2647 - accuracy: 0.9009
# Epoch 12/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2572 - accuracy: 0.9049
# Epoch 13/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2535 - accuracy: 0.9046
# Epoch 14/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2461 - accuracy: 0.9068
# Epoch 15/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2423 - accuracy: 0.9092
# Epoch 16/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2364 - accuracy: 0.9118
# Epoch 17/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2343 - accuracy: 0.9110
# Epoch 18/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2284 - accuracy: 0.9130
# Epoch 19/25
# 469/469 [==============================] - 7s 16ms/step - loss: 0.2231 - accuracy: 0.9153
# Epoch 20/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2169 - accuracy: 0.9183
# Epoch 21/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2146 - accuracy: 0.9186
# Epoch 22/25
# 469/469 [==============================] - 6s 13ms/step - loss: 0.2123 - accuracy: 0.9190
# Epoch 23/25
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2063 - accuracy: 0.9228
# Epoch 24/25
# 469/469 [==============================] - 8s 17ms/step - loss: 0.2080 - accuracy: 0.9201
# Epoch 25/25
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1976 - accuracy: 0.9237

# %%
train_accuracy_df = pd.DataFrame()
train_accuracy_df['K'] = training_accuracy.keys()
train_accuracy_df['Training Accuracy'] = training_accuracy.values()
train_accuracy_df
# Out:
#     K  Training Accuracy
# 0  10             0.9234
# 1  20             0.9231
# 2  30             0.9228
# 3  40             0.9240
# 4  50             0.9237

# %% [markdown]
# ### 7. Model Evaluation

# %%
# One hot encode the test target variable
new_y_test = to_categorical(y_test)

# %%
# testing accuracy
testing_accuracy = {}

for k in k_values:
  accuracy = models[k].evaluate(X_test, new_y_test, batch_size=128)[1]
  testing_accuracy[k] = round(accuracy, 4)
# Out:
# 79/79 [==============================] - 1s 7ms/step - loss: 0.3074 - accuracy: 0.8962
# 79/79 [==============================] - 1s 6ms/step - loss: 0.3166 - accuracy: 0.8949
# 79/79 [==============================] - 1s 6ms/step - loss: 0.3171 - accuracy: 0.8954
# 79/79 [==============================] - 1s 6ms/step - loss: 0.3178 - accuracy: 0.8941
# 79/79 [==============================] - 1s 5ms/step - loss: 0.3118 - accuracy: 0.8939

# %%
test_accuracy_df = pd.DataFrame()
test_accuracy_df['K'] = testing_accuracy.keys()
test_accuracy_df['Testing Accuracy'] = testing_accuracy.values()
test_accuracy_df
# Out:
#     K  Testing Accuracy
# 0  10            0.8962
# 1  20            0.8949
# 2  30            0.8954
# 3  40            0.8941
# 4  50            0.8939
